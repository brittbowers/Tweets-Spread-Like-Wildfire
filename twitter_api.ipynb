# %%
import tweepy
import os
import pandas as pd

# %%
# Authenticate to Twitter
auth = tweepy.OAuthHandler("n3rpM5i1xDH4X7tWcg51wK5Gd", "WMPDYP87KwsGZCT4dx8Tsun0Yn9HxGtGCL0wpL2F20lmgpPR9d")
auth.set_access_token("1192516987894714368-4wdTTFvVYq13mSxr0sknyf4i6RfweG","gngDz0JcBrwiT4sG99QN9tqP6dbXco1cSXkKAGPi3XCvO")

api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True,
                parser=tweepy.parsers.JSONParser())

# test authentication
try:
    api.verify_credentials()
    print("Authentication OK")
except:
    print("Error during authentication")

api.search(q="#campfire", lang="en", count=10)
# Out:
# Authentication OK
# {'statuses': [{'created_at': 'Sat Nov 09 20:06:28 +0000 2019',
#    'id': 1193258576204222469,
#    'id_str': '1193258576204222469',
#    'text': 'RT @RV4CampfireFams: My 7 year old and I are driving a donated RV from Denver to #Paradise, CA this weekend to gift it to a single mom with…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Paradise', 'indices': [81, 90]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'RV4CampfireFams',
#       'name': 'RV4CampfireFamily',
#       'id': 1068772238369808385,
#       'id_str': '1068772238369808385',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 821873849176358912,
#     'id_str': '821873849176358912',
#     'name': 'Kathy Huffman',
#     'screen_name': 'KathyHoldshope',
#     'location': '',
#     'description': '#RESIST #KEEPKRATOMLEGAL #WATERISLIFE #FreeRealityWinner',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 7950,
#     'friends_count': 7955,
#     'listed_count': 7,
#     'created_at': 'Thu Jan 19 00:16:10 +0000 2017',
#     'favourites_count': 35222,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 86534,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/927213044211568641/AuOBUcgC_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/927213044211568641/AuOBUcgC_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Nov 08 01:24:13 +0000 2019',
#     'id': 1192613764476088320,
#     'id_str': '1192613764476088320',
#     'text': 'My 7 year old and I are driving a donated RV from Denver to #Paradise, CA this weekend to gift it to a single mom w… https://t.co/x5bJYyeeVd',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Paradise', 'indices': [60, 69]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/x5bJYyeeVd',
#        'expanded_url': 'https://twitter.com/i/web/status/1192613764476088320',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1068772238369808385,
#      'id_str': '1068772238369808385',
#      'name': 'RV4CampfireFamily',
#      'screen_name': 'RV4CampfireFams',
#      'location': 'United States',
#      'description': '',
#      'url': 'https://t.co/mnZBUkMipc',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/mnZBUkMipc',
#          'expanded_url': 'https://www.gofundme.com/motor-home-for-fire-victims',
#          'display_url': 'gofundme.com/motor-home-for…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 668,
#      'friends_count': 838,
#      'listed_count': 3,
#      'created_at': 'Sat Dec 01 07:42:13 +0000 2018',
#      'favourites_count': 637,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 333,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1068772375234138112/sL19Lm2f_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1068772375234138112/sL19Lm2f_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1068772238369808385/1543771566',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 10,
#     'favorite_count': 19,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 10,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Nov 09 20:06:26 +0000 2019',
#    'id': 1193258564917313536,
#    'id_str': '1193258564917313536',
#    'text': 'RT @lizziejohnsonnn: “Silence for the keys that no longer open front doors.\n\nFor the neighbors who moved away and for the friends who died…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'lizziejohnsonnn',
#       'name': 'Lizzie Johnson',
#       'id': 341342503,
#       'id_str': '341342503',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1177656509456670721,
#     'id_str': '1177656509456670721',
#     'name': 'Holy Name Men’s Club',
#     'screen_name': 'HolyNameMen',
#     'location': '',
#     'description': 'The Holy Name Men’s Club of Omaha, Nebraska. We are a non-profit organization supporting Holy Name School and parish. You might have heard of our fish fry.',
#     'url': 'https://t.co/M7W7ttB1hD',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/M7W7ttB1hD',
#         'expanded_url': 'http://www.holynamemensclub.org',
#         'display_url': 'holynamemensclub.org',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 9,
#     'friends_count': 66,
#     'listed_count': 0,
#     'created_at': 'Fri Sep 27 18:50:21 +0000 2019',
#     'favourites_count': 107,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 121,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1177660795641061376/r2qjOA78_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1177660795641061376/r2qjOA78_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1177656509456670721/1569611038',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Nov 09 00:29:51 +0000 2019',
#     'id': 1192962469703999488,
#     'id_str': '1192962469703999488',
#     'text': '“Silence for the keys that no longer open front doors.\n\nFor the neighbors who moved away and for the friends who di… https://t.co/L00D6E7KO8',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/L00D6E7KO8',
#        'expanded_url': 'https://twitter.com/i/web/status/1192962469703999488',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 341342503,
#      'id_str': '341342503',
#      'name': 'Lizzie Johnson',
#      'screen_name': 'lizziejohnsonnn',
#      'location': 'California',
#      'description': 'Reporter at the @sfchronicle covering wildfires + more. Writing a book on the #CampFire for @CrownPublishing. Nebraska nice. Say hi 👋🏻ljohnson@sfchronicle.com',
#      'url': 'https://t.co/C36X3ZzYaT',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/C36X3ZzYaT',
#          'expanded_url': 'http://bit.ly/1IeZbZO',
#          'display_url': 'bit.ly/1IeZbZO',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 12441,
#      'friends_count': 1511,
#      'listed_count': 349,
#      'created_at': 'Sun Jul 24 06:25:41 +0000 2011',
#      'favourites_count': 5530,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 8446,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1192952451046891522/0Pz95m3n_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1192952451046891522/0Pz95m3n_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/341342503/1572465777',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': '56C787',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 36,
#     'favorite_count': 69,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 36,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Nov 09 20:06:19 +0000 2019',
#    'id': 1193258534957391873,
#    'id_str': '1193258534957391873',
#    'text': 'RT @RV4CampfireFams: Sending our love to everyone here who is bravely facing today. Whether you’re angry, scared, sad, or not feeling anyth…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'RV4CampfireFams',
#       'name': 'RV4CampfireFamily',
#       'id': 1068772238369808385,
#       'id_str': '1068772238369808385',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 821873849176358912,
#     'id_str': '821873849176358912',
#     'name': 'Kathy Huffman',
#     'screen_name': 'KathyHoldshope',
#     'location': '',
#     'description': '#RESIST #KEEPKRATOMLEGAL #WATERISLIFE #FreeRealityWinner',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 7950,
#     'friends_count': 7955,
#     'listed_count': 7,
#     'created_at': 'Thu Jan 19 00:16:10 +0000 2017',
#     'favourites_count': 35222,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 86534,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/927213044211568641/AuOBUcgC_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/927213044211568641/AuOBUcgC_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Nov 08 17:46:53 +0000 2019',
#     'id': 1192861060803551232,
#     'id_str': '1192861060803551232',
#     'text': 'Sending our love to everyone here who is bravely facing today. Whether you’re angry, scared, sad, or not feeling an… https://t.co/2rftXXbceZ',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/2rftXXbceZ',
#        'expanded_url': 'https://twitter.com/i/web/status/1192861060803551232',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1068772238369808385,
#      'id_str': '1068772238369808385',
#      'name': 'RV4CampfireFamily',
#      'screen_name': 'RV4CampfireFams',
#      'location': 'United States',
#      'description': '',
#      'url': 'https://t.co/mnZBUkMipc',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/mnZBUkMipc',
#          'expanded_url': 'https://www.gofundme.com/motor-home-for-fire-victims',
#          'display_url': 'gofundme.com/motor-home-for…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 668,
#      'friends_count': 838,
#      'listed_count': 3,
#      'created_at': 'Sat Dec 01 07:42:13 +0000 2018',
#      'favourites_count': 637,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 333,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1068772375234138112/sL19Lm2f_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1068772375234138112/sL19Lm2f_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1068772238369808385/1543771566',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 11,
#     'favorite_count': 17,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 11,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Nov 09 20:06:09 +0000 2019',
#    'id': 1193258496453529600,
#    'id_str': '1193258496453529600',
#    'text': 'RT @mkewman: A quick reminder: The #CampFire started on Federal Land. Trump Cut the USFS Budget for hazardous vegetation removal and forest…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'CampFire', 'indices': [35, 44]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'mkewman',
#       'name': 'Mark Kewman',
#       'id': 9777822,
#       'id_str': '9777822',
#       'indices': [3, 11]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 905854419329093632,
#     'id_str': '905854419329093632',
#     'name': 'Charlie',
#     'screen_name': 'nudog71',
#     'location': 'United States',
#     'description': 'Veteran, Human Rights, Animal Rights #RESIST #NOTMYPRESIDENT #BlackLivesMatter #ImmigrantLivesMatter  #LGBTQ #OneLove #FBR NO LISTS',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 11614,
#     'friends_count': 11264,
#     'listed_count': 5,
#     'created_at': 'Thu Sep 07 18:04:58 +0000 2017',
#     'favourites_count': 43979,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 81258,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/905856665701965824/SflrBlBA_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/905856665701965824/SflrBlBA_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/905854419329093632/1558716873',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Nov 09 15:11:47 +0000 2019',
#     'id': 1193184413145677824,
#     'id_str': '1193184413145677824',
#     'text': 'A quick reminder: The #CampFire started on Federal Land. Trump Cut the USFS Budget for hazardous vegetation removal… https://t.co/144nAODwIU',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'CampFire', 'indices': [22, 31]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/144nAODwIU',
#        'expanded_url': 'https://twitter.com/i/web/status/1193184413145677824',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 9777822,
#      'id_str': '9777822',
#      'name': 'Mark Kewman',
#      'screen_name': 'mkewman',
#      'location': 'Sacramento, CA',
#      'description': 'Current Broadcast Engineer and Emmy Nominated Former Assignment Editor for @CBSSacramento, Radio DJ. Opinions ≠ employer. RT≠Endorsement. Proud Dad of Maggie',
#      'url': 'https://t.co/raSZH3KSDf',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/raSZH3KSDf',
#          'expanded_url': 'http://www.cbs13.com',
#          'display_url': 'cbs13.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1257,
#      'friends_count': 2816,
#      'listed_count': 36,
#      'created_at': 'Mon Oct 29 15:36:11 +0000 2007',
#      'favourites_count': 13088,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 19929,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/630250380014686208/fWJMkRVK_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/630250380014686208/fWJMkRVK_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/9777822/1465875590',
#      'profile_link_color': '696969',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 13,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Nov 09 20:05:50 +0000 2019',
#    'id': 1193258413209182208,
#    'id_str': '1193258413209182208',
#    'text': 'RT @mkewman: A quick reminder: The #CampFire started on Federal Land. Trump Cut the USFS Budget for hazardous vegetation removal and forest…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'CampFire', 'indices': [35, 44]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'mkewman',
#       'name': 'Mark Kewman',
#       'id': 9777822,
#       'id_str': '9777822',
#       'indices': [3, 11]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 872578169492054017,
#     'id_str': '872578169492054017',
#     'name': 'Red 🗽🗯',
#     'screen_name': 'NoPuppet_007',
#     'location': '📍👈',
#     'description': 'Progressive; #RESISTANCE;🦠#GeeksResist; ‘retired’ punk; brain surgery veteran + #CPP♿️. #TN/#TrigeminalNeuralgia is my nemesis. #RedneckHitler needs to go.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 885,
#     'friends_count': 1277,
#     'listed_count': 3,
#     'created_at': 'Wed Jun 07 22:17:02 +0000 2017',
#     'favourites_count': 13052,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 15507,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1046926248763580418/txbVoZW0_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1046926248763580418/txbVoZW0_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/872578169492054017/1570821244',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Nov 09 15:11:47 +0000 2019',
#     'id': 1193184413145677824,
#     'id_str': '1193184413145677824',
#     'text': 'A quick reminder: The #CampFire started on Federal Land. Trump Cut the USFS Budget for hazardous vegetation removal… https://t.co/144nAODwIU',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'CampFire', 'indices': [22, 31]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/144nAODwIU',
#        'expanded_url': 'https://twitter.com/i/web/status/1193184413145677824',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 9777822,
#      'id_str': '9777822',
#      'name': 'Mark Kewman',
#      'screen_name': 'mkewman',
#      'location': 'Sacramento, CA',
#      'description': 'Current Broadcast Engineer and Emmy Nominated Former Assignment Editor for @CBSSacramento, Radio DJ. Opinions ≠ employer. RT≠Endorsement. Proud Dad of Maggie',
#      'url': 'https://t.co/raSZH3KSDf',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/raSZH3KSDf',
#          'expanded_url': 'http://www.cbs13.com',
#          'display_url': 'cbs13.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1257,
#      'friends_count': 2816,
#      'listed_count': 36,
#      'created_at': 'Mon Oct 29 15:36:11 +0000 2007',
#      'favourites_count': 13088,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 19929,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/630250380014686208/fWJMkRVK_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/630250380014686208/fWJMkRVK_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/9777822/1465875590',
#      'profile_link_color': '696969',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 13,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Nov 09 20:05:07 +0000 2019',
#    'id': 1193258235366723584,
#    'id_str': '1193258235366723584',
#    'text': 'RT @ThisOldHouse: Group photo! Here’s the whole motley crew at our most recent “wrap party,” where we gather to mark the conclusion of a pr…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ThisOldHouse',
#       'name': 'This Old House',
#       'id': 36376198,
#       'id_str': '36376198',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 33170340,
#     'id_str': '33170340',
#     'name': 'Paul Parisi Jr 🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f🇮🇹',
#     'screen_name': 'paulparisijr',
#     'location': 'Concord NH',
#     'description': '🇺🇸#SEIU Concord NH Plymouth State alumni. Gloucester MA PROUD! political junkie. Also A loyal Fan of Chelsea FC and the Boston Red Sox.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 82,
#     'friends_count': 69,
#     'listed_count': 3,
#     'created_at': 'Sun Apr 19 09:50:16 +0000 2009',
#     'favourites_count': 6524,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 4053,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C6E2EE',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/865160073265397761/0yGSn2E0_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/865160073265397761/0yGSn2E0_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/33170340/1495105212',
#     'profile_link_color': '1F98C7',
#     'profile_sidebar_border_color': 'C6E2EE',
#     'profile_sidebar_fill_color': 'DAECF4',
#     'profile_text_color': '663B12',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Nov 09 17:52:41 +0000 2019',
#     'id': 1193224906516942851,
#     'id_str': '1193224906516942851',
#     'text': 'Group photo! Here’s the whole motley crew at our most recent “wrap party,” where we gather to mark the conclusion o… https://t.co/c5Mek0fuA9',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/c5Mek0fuA9',
#        'expanded_url': 'https://twitter.com/i/web/status/1193224906516942851',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 36376198,
#      'id_str': '36376198',
#      'name': 'This Old House',
#      'screen_name': 'ThisOldHouse',
#      'location': 'United States',
#      'description': 'Celebrating 40 years of trusted home improvement information and expert advice. #PBS',
#      'url': 'https://t.co/tyrnAo3yax',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/tyrnAo3yax',
#          'expanded_url': 'http://thisoldhouse.com',
#          'display_url': 'thisoldhouse.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 203053,
#      'friends_count': 662,
#      'listed_count': 1610,
#      'created_at': 'Wed Apr 29 14:55:07 +0000 2009',
#      'favourites_count': 7463,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 23878,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '003399',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/921085566199975936/uqeB-STH_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/921085566199975936/uqeB-STH_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/36376198/1501172593',
#      'profile_link_color': '000080',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'FFFFFF',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 4,
#     'favorite_count': 69,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Nov 09 20:04:51 +0000 2019',
#    'id': 1193258168694059010,
#    'id_str': '1193258168694059010',
#    'text': 'Really had a lot of fun 😍\n#oman #mountains #traveling #offroad #jabelshams #CampFire https://t.co/sbMFdB1CR4',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'oman', 'indices': [26, 31]},
#      {'text': 'mountains', 'indices': [32, 42]},
#      {'text': 'traveling', 'indices': [43, 53]},
#      {'text': 'offroad', 'indices': [54, 62]},
#      {'text': 'jabelshams', 'indices': [63, 74]},
#      {'text': 'CampFire', 'indices': [75, 84]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1193257716103421958,
#       'id_str': '1193257716103421958',
#       'indices': [85, 108],
#       'media_url': 'http://pbs.twimg.com/media/EI9NkhXWoAY2b8m.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EI9NkhXWoAY2b8m.jpg',
#       'url': 'https://t.co/sbMFdB1CR4',
#       'display_url': 'pic.twitter.com/sbMFdB1CR4',
#       'expanded_url': 'https://twitter.com/RISHIPK_7/status/1193258168694059010/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1536, 'h': 2048, 'resize': 'fit'},
#        'small': {'w': 510, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 900, 'h': 1200, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1193257716103421958,
#       'id_str': '1193257716103421958',
#       'indices': [85, 108],
#       'media_url': 'http://pbs.twimg.com/media/EI9NkhXWoAY2b8m.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EI9NkhXWoAY2b8m.jpg',
#       'url': 'https://t.co/sbMFdB1CR4',
#       'display_url': 'pic.twitter.com/sbMFdB1CR4',
#       'expanded_url': 'https://twitter.com/RISHIPK_7/status/1193258168694059010/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1536, 'h': 2048, 'resize': 'fit'},
#        'small': {'w': 510, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 900, 'h': 1200, 'resize': 'fit'}}},
#      {'id': 1193257813193187328,
#       'id_str': '1193257813193187328',
#       'indices': [85, 108],
#       'media_url': 'http://pbs.twimg.com/media/EI9NqLDW4AAaB5u.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EI9NqLDW4AAaB5u.jpg',
#       'url': 'https://t.co/sbMFdB1CR4',
#       'display_url': 'pic.twitter.com/sbMFdB1CR4',
#       'expanded_url': 'https://twitter.com/RISHIPK_7/status/1193258168694059010/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 900, 'h': 1200, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 510, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 1536, 'h': 2048, 'resize': 'fit'}}},
#      {'id': 1193257914821218305,
#       'id_str': '1193257914821218305',
#       'indices': [85, 108],
#       'media_url': 'http://pbs.twimg.com/media/EI9NwFpXkAEOcUf.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EI9NwFpXkAEOcUf.jpg',
#       'url': 'https://t.co/sbMFdB1CR4',
#       'display_url': 'pic.twitter.com/sbMFdB1CR4',
#       'expanded_url': 'https://twitter.com/RISHIPK_7/status/1193258168694059010/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1638, 'h': 2048, 'resize': 'fit'},
#        'medium': {'w': 960, 'h': 1200, 'resize': 'fit'},
#        'small': {'w': 544, 'h': 680, 'resize': 'fit'}}},
#      {'id': 1193258042357436423,
#       'id_str': '1193258042357436423',
#       'indices': [85, 108],
#       'media_url': 'http://pbs.twimg.com/media/EI9N3gwX0AcDeR_.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EI9N3gwX0AcDeR_.jpg',
#       'url': 'https://t.co/sbMFdB1CR4',
#       'display_url': 'pic.twitter.com/sbMFdB1CR4',
#       'expanded_url': 'https://twitter.com/RISHIPK_7/status/1193258168694059010/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 2048, 'h': 2048, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 680, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1181224267,
#     'id_str': '1181224267',
#     'name': 'ऋഷി',
#     'screen_name': 'RISHIPK_7',
#     'location': 'Kozhikode, India',
#     'description': 'I’m real and I hope some of my followers are too',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 25,
#     'friends_count': 573,
#     'listed_count': 0,
#     'created_at': 'Fri Feb 15 05:37:59 +0000 2013',
#     'favourites_count': 1707,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 333,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1183114048927342592/ty1p05nR_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1183114048927342592/ty1p05nR_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1181224267/1498384145',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '017e1bc3486db84f',
#     'url': 'https://api.twitter.com/1.1/geo/id/017e1bc3486db84f.json',
#     'place_type': 'admin',
#     'name': 'Al Dakhiliyah',
#     'full_name': 'Al Dakhiliyah, Oman',
#     'country_code': 'OM',
#     'country': 'Oman',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[55.0788158, 17.0457782],
#        [58.1403343, 17.0457782],
#        [58.1403343, 23.5347324],
#        [55.0788158, 23.5347324]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Nov 09 20:04:11 +0000 2019',
#    'id': 1193257997893398528,
#    'id_str': '1193257997893398528',
#    'text': 'RT @Jasamsdestiny: #CampFire\nAnd the mystery of who owned the icon flag in Paradise has been solved!\n\nhttps://t.co/Gz17fHmviU\n\n#Paradise #M…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'CampFire', 'indices': [19, 28]},
#      {'text': 'Paradise', 'indices': [127, 136]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Jasamsdestiny',
#       'name': 'Tay Austin',
#       'id': 129877411,
#       'id_str': '129877411',
#       'indices': [3, 17]}],
#     'urls': [{'url': 'https://t.co/Gz17fHmviU',
#       'expanded_url': 'https://www.actionnewsnow.com/content/news/THE-FLAG-the-story-of-an-American-Flag-that-survived-the-fire-to-become-a-symbol-of-hope-564662891.html',
#       'display_url': 'actionnewsnow.com/content/news/T…',
#       'indices': [102, 125]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1877444256,
#     'id_str': '1877444256',
#     'name': 'Susie',
#     'screen_name': 'SuzChaos',
#     'location': 'Santa Barbara, CA',
#     'description': 'Mostly a data aggregator for stuff you should know. Cute animals too because they make everything better!',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 281,
#     'friends_count': 891,
#     'listed_count': 22,
#     'created_at': 'Wed Sep 18 00:53:43 +0000 2013',
#     'favourites_count': 42570,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 39852,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000471674233/8052468a1c4adf98c33573b54f72a8b9_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000471674233/8052468a1c4adf98c33573b54f72a8b9_normal.jpeg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Nov 09 19:55:42 +0000 2019',
#     'id': 1193255865471688704,
#     'id_str': '1193255865471688704',
#     'text': '#CampFire\nAnd the mystery of who owned the icon flag in Paradise has been solved!\n\nhttps://t.co/Gz17fHmviU… https://t.co/Azmdt1AUlf',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'CampFire', 'indices': [0, 9]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/Gz17fHmviU',
#        'expanded_url': 'https://www.actionnewsnow.com/content/news/THE-FLAG-the-story-of-an-American-Flag-that-survived-the-fire-to-become-a-symbol-of-hope-564662891.html',
#        'display_url': 'actionnewsnow.com/content/news/T…',
#        'indices': [83, 106]},
#       {'url': 'https://t.co/Azmdt1AUlf',
#        'expanded_url': 'https://twitter.com/i/web/status/1193255865471688704',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [108, 131]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 129877411,
#      'id_str': '129877411',
#      'name': 'Tay Austin',
#      'screen_name': 'Jasamsdestiny',
#      'location': '#TheResistance #Democracy #Truth   #Foster #Adopt  No pet left behind 🐾',
#      'description': 'Disaster Assist Team  #DAT   🌬️ \n We do our best to keep you safe and informed',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2009,
#      'friends_count': 90,
#      'listed_count': 100,
#      'created_at': 'Mon Apr 05 17:46:11 +0000 2010',
#      'favourites_count': 146,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 42337,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'FAFAFA',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/757325211368878080/vPoqaNIt_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/757325211368878080/vPoqaNIt_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/129877411/1469395020',
#      'profile_link_color': '4B6693',
#      'profile_sidebar_border_color': '333333',
#      'profile_sidebar_fill_color': '6A6A6B',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Nov 09 20:03:59 +0000 2019',
#    'id': 1193257948119752704,
#    'id_str': '1193257948119752704',
#    'text': 'What a wonderful tribute to #Paradise...#Concow....#Magalia...#Pulga.   Now not only will Nov 8th be a day of Remem… https://t.co/6xviGvObiB',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Paradise', 'indices': [28, 37]},
#      {'text': 'Concow', 'indices': [40, 47]},
#      {'text': 'Magalia', 'indices': [51, 59]},
#      {'text': 'Pulga', 'indices': [62, 68]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/6xviGvObiB',
#       'expanded_url': 'https://twitter.com/i/web/status/1193257948119752704',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 129877411,
#     'id_str': '129877411',
#     'name': 'Tay Austin',
#     'screen_name': 'Jasamsdestiny',
#     'location': '#TheResistance #Democracy #Truth   #Foster #Adopt  No pet left behind 🐾',
#     'description': 'Disaster Assist Team  #DAT   🌬️ \n We do our best to keep you safe and informed',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2009,
#     'friends_count': 90,
#     'listed_count': 100,
#     'created_at': 'Mon Apr 05 17:46:11 +0000 2010',
#     'favourites_count': 146,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 42337,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FAFAFA',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/757325211368878080/vPoqaNIt_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/757325211368878080/vPoqaNIt_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/129877411/1469395020',
#     'profile_link_color': '4B6693',
#     'profile_sidebar_border_color': '333333',
#     'profile_sidebar_fill_color': '6A6A6B',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1193236561745399808,
#    'quoted_status_id_str': '1193236561745399808',
#    'quoted_status': {'created_at': 'Sat Nov 09 18:39:00 +0000 2019',
#     'id': 1193236561745399808,
#     'id_str': '1193236561745399808',
#     'text': 'In a proclamation signed by Governor Newsom, Nov. 8 will now be recognized as "California Resilience Day". Read abo… https://t.co/mT0W3XSMmd',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mT0W3XSMmd',
#        'expanded_url': 'https://twitter.com/i/web/status/1193236561745399808',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.socialnewsdesk.com" rel="nofollow">SocialNewsDesk</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 43942200,
#      'id_str': '43942200',
#      'name': 'Action News Now',
#      'screen_name': 'ActionNewsNow',
#      'location': 'Chico, CA',
#      'description': 'KHSL-TV & KNVN Action News Now CBS 12 & NBC 24 Chico/Redding, CA',
#      'url': 'https://t.co/dg1YvEzL0B',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/dg1YvEzL0B',
#          'expanded_url': 'http://www.actionnewsnow.com',
#          'display_url': 'actionnewsnow.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 17746,
#      'friends_count': 422,
#      'listed_count': 356,
#      'created_at': 'Mon Jun 01 18:44:04 +0000 2009',
#      'favourites_count': 1535,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 48153,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '11BAED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/955830377733545984/JhptxLYU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/955830377733545984/JhptxLYU_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/43942200/1572041970',
#      'profile_link_color': '00AEFF',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'D1D1D1',
#      'profile_text_color': '050200',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 5,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Nov 09 20:00:24 +0000 2019',
#    'id': 1193257049762811906,
#    'id_str': '1193257049762811906',
#    'text': "RT @Jasamsdestiny: I bet some of you didn't know that #Magalia's beautiful new sign was actually built by #CalFire's Lassen-Modoc Unit &amp; in…",
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Magalia', 'indices': [54, 62]},
#      {'text': 'CalFire', 'indices': [106, 114]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Jasamsdestiny',
#       'name': 'Tay Austin',
#       'id': 129877411,
#       'id_str': '129877411',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 17428614,
#     'id_str': '17428614',
#     'name': 'Cheaptarts 🌊🍍🦋',
#     'screen_name': 'Cheaptarts',
#     'location': 'Dallas, TX',
#     'description': 'Enjoying the struggle between design & color in creating 🎨 Always reading! #ilovehawaii 🌴🌺',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1139,
#     'friends_count': 526,
#     'listed_count': 106,
#     'created_at': 'Sun Nov 16 22:00:47 +0000 2008',
#     'favourites_count': 72123,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 138062,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/503682994/fierce-4-U-me_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/503682994/fierce-4-U-me_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17428614/1429414214',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'A8C7F7',
#     'profile_sidebar_fill_color': 'C0DFEC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Nov 09 19:46:50 +0000 2019',
#     'id': 1193253632210296836,
#     'id_str': '1193253632210296836',
#     'text': "I bet some of you didn't know that #Magalia's beautiful new sign was actually built by #CalFire's Lassen-Modoc Unit… https://t.co/K2krQ4XAqP",
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Magalia', 'indices': [35, 43]},
#       {'text': 'CalFire', 'indices': [87, 95]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/K2krQ4XAqP',
#        'expanded_url': 'https://twitter.com/i/web/status/1193253632210296836',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 129877411,
#      'id_str': '129877411',
#      'name': 'Tay Austin',
#      'screen_name': 'Jasamsdestiny',
#      'location': '#TheResistance #Democracy #Truth   #Foster #Adopt  No pet left behind 🐾',
#      'description': 'Disaster Assist Team  #DAT   🌬️ \n We do our best to keep you safe and informed',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2009,
#      'friends_count': 90,
#      'listed_count': 100,
#      'created_at': 'Mon Apr 05 17:46:11 +0000 2010',
#      'favourites_count': 146,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 42337,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'FAFAFA',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/757325211368878080/vPoqaNIt_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/757325211368878080/vPoqaNIt_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/129877411/1469395020',
#      'profile_link_color': '4B6693',
#      'profile_sidebar_border_color': '333333',
#      'profile_sidebar_fill_color': '6A6A6B',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.041,
#   'max_id': 1193258576204222469,
#   'max_id_str': '1193258576204222469',
#   'next_results': '?max_id=1193257049762811905&q=%23campfire&lang=en&count=10&include_entities=1',
#   'query': '%23campfire',
#   'refresh_url': '?since_id=1193258576204222469&q=%23campfire&lang=en&include_entities=1',
#   'count': 10,
#   'since_id': 0,
#   'since_id_str': '0'}}
